# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')
# %matplotlib inline

# %%
df=pd.read_csv('C:/Users/hp/Desktop/Finance Risk Analytics/FRA Assign 1/Market_risk_dataset.csv')

# %%
df
# Out:
#            Date  Infosys  Indian Hotel  Mahindra & Mahindra  Axis Bank  SAIL  \
# 0    31-03-2014      264            69                  455        263    68
# 1    07-04-2014      257            68                  458        276    70
# 2    14-04-2014      254            68                  454        270    68
# 3    21-04-2014      253            68                  488        283    68
# 4    28-04-2014      256            65                  482        282    63
# ..          ...      ...           ...                  ...        ...   ...
# 309  02-03-2020      729           120                  469        658    33
# 310  09-03-2020      634           114                  427        569    30
# 311  16-03-2020      577            90                  321        428    27
# 312  23-03-2020      644            75                  293        360    21
# 313  30-03-2020      633            75                  284        379    23
#
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Infosys', 'Indian Hotel', 'Mahindra & Mahindra', 'Axis Bank',
#        'SAIL', 'Shree Cement', 'Sun Pharma', 'Jindal Steel', 'Idea Vodafone',
#        'Jet Airways'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(' ','_')

# %%
df.columns
# Out:
# Index(['Date', 'Infosys', 'Indian_Hotel', 'Mahindra_&_Mahindra', 'Axis_Bank',
#        'SAIL', 'Shree_Cement', 'Sun_Pharma', 'Jindal_Steel', 'Idea_Vodafone',
#        'Jet_Airways'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 314 entries, 0 to 313
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Date                 314 non-null    object
#  1   Infosys              314 non-null    int64
#  2   Indian_Hotel         314 non-null    int64
#  3   Mahindra_&_Mahindra  314 non-null    int64
#  4   Axis_Bank            314 non-null    int64
#  5   SAIL                 314 non-null    int64
#  6   Shree_Cement         314 non-null    int64
#  7   Sun_Pharma           314 non-null    int64
#  8   Jindal_Steel         314 non-null    int64
#  9   Idea_Vodafone        314 non-null    int64
#  10  Jet_Airways          314 non-null    int64
# dtypes: int64(10), object(1)
# memory usage: 27.1+ KB

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['Infosys'], edgecolors='b', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('infosys_stock_price')
plt.title('Infosys over the years')
plt.savefig('infosys_stock_price.png')
plt.show()

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['Indian_Hotel'], edgecolors='r', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('Indian_Hotel')
plt.title('Indian_Hotel over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['Mahindra_&_Mahindra'], edgecolors='b', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('Mahindra_&_Mahindra')
plt.title('Mahindra_&_Mahindra over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['Axis_Bank'], edgecolors='r', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('Axis_Bank')
plt.title('Axis_Bank over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['SAIL'], edgecolors='b', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('SAIL')
plt.title('SAIL over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['Shree_Cement'], edgecolors='r', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('Shree_Cement')
plt.title('Shree_Cement over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['Sun_Pharma'], edgecolors='b', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('Sun_Pharma')
plt.title('Sun_Pharma over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['Jindal_Steel'], edgecolors='r', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('Jindal_Steel')
plt.title('Jindal_Steel over the years')
plt.show()

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['Idea_Vodafone'], edgecolors='r', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('Idea_Vodafone_stock_price')
plt.title('Idea_Vodafone over the years')

plt.show()

# %%
plt.figure(figsize = (10, 8))
df['dates'] = [pd.to_datetime(d) for d in df['Date']]
plt.scatter(df['dates'], df['Jet_Airways'], edgecolors='r', color = 'lightblue')
plt.xlabel('Year')
plt.ylabel('Jet_Airways')
plt.title('Jet_Airways over the years')
plt.show()

# %%
df.columns
# Out:
# Index(['Date', 'Infosys', 'Indian_Hotel', 'Mahindra_&_Mahindra', 'Axis_Bank',
#        'SAIL', 'Shree_Cement', 'Sun_Pharma', 'Jindal_Steel', 'Idea_Vodafone',
#        'Jet_Airways', 'dates'],
#       dtype='object')

# %% [markdown]
# # Analysing Return

# %% [raw]
# Steps for calculating returns from prices:
#
# 1. Take logarithms
# 2. Take differences

# %%
df_returns = np.log(df.drop(['Date','dates'],axis=1)).diff(axis = 0, periods = 1)

# %%
df_returns
# Out:
#       Infosys  Indian_Hotel  Mahindra_&_Mahindra  Axis_Bank      SAIL  \
# 0         NaN           NaN                  NaN        NaN       NaN
# 1   -0.026873     -0.014599             0.006572   0.048247  0.028988
# 2   -0.011742      0.000000            -0.008772  -0.021979 -0.028988
# 3   -0.003945      0.000000             0.072218   0.047025  0.000000
# 4    0.011788     -0.045120            -0.012371  -0.003540 -0.076373
# ..        ...           ...                  ...        ...       ...
# 309  0.009649     -0.110348             0.030305  -0.057580 -0.087011
# 310 -0.139625     -0.051293            -0.093819  -0.145324 -0.095310
# 311 -0.094207     -0.236389            -0.285343  -0.284757 -0.105361
# 312  0.109856     -0.182322            -0.091269  -0.173019 -0.251314
# 313 -0.017228      0.000000            -0.031198   0.051432  0.090972
#
#      Shree_Cement  Sun_Pharma  Jindal_Steel  Idea_Vodafone  Jet_Airways
# ...

# %% [markdown]
# # Checking the rows & columns of datases

# %%
df_returns.shape
# Out:
# (314, 10)

# %% [markdown]
# *checking top 5 rows*

# %%
df_returns.head()
# Out:
#     Infosys  Indian_Hotel  Mahindra_&_Mahindra  Axis_Bank      SAIL  \
# 0       NaN           NaN                  NaN        NaN       NaN
# 1 -0.026873     -0.014599             0.006572   0.048247  0.028988
# 2 -0.011742      0.000000            -0.008772  -0.021979 -0.028988
# 3 -0.003945      0.000000             0.072218   0.047025  0.000000
# 4  0.011788     -0.045120            -0.012371  -0.003540 -0.076373
#
#    Shree_Cement  Sun_Pharma  Jindal_Steel  Idea_Vodafone  Jet_Airways
# 0           NaN         NaN           NaN            NaN          NaN
# 1      0.032831    0.094491     -0.065882       0.011976     0.086112
# 2     -0.013888   -0.004930      0.000000      -0.011976    -0.078943
# 3      0.007583   -0.004955     -0.018084       0.000000     0.007117
# 4     -0.019515    0.011523     -0.140857      -0.049393    -0.148846

# %% [markdown]
# # Calculating stock means

# %%
df_means = df_returns.mean(axis = 0)
df_means
# Out:
# Infosys                0.002794
# Indian_Hotel           0.000266
# Mahindra_&_Mahindra   -0.001506
# Axis_Bank              0.001167
# SAIL                  -0.003463
# Shree_Cement           0.003681
# Sun_Pharma            -0.001455
# Jindal_Steel          -0.004123
# Idea_Vodafone         -0.010608
# Jet_Airways           -0.009548
# dtype: float64

# %% [markdown]
# # Calculating stock Standard Deviation

# %%
df_std = df_returns.std(axis = 0)
df_std
# Out:
# Infosys                0.035070
# Indian_Hotel           0.047131
# Mahindra_&_Mahindra    0.040169
# Axis_Bank              0.045828
# SAIL                   0.062188
# Shree_Cement           0.039917
# Sun_Pharma             0.045033
# Jindal_Steel           0.075108
# Idea_Vodafone          0.104315
# Jet_Airways            0.097972
# dtype: float64

# %%
df_summary = pd.DataFrame({'Average':df_means, 'Volatility': df_std})
df_summary
# Out:
#                       Average  Volatility
# Infosys              0.002794    0.035070
# Indian_Hotel         0.000266    0.047131
# Mahindra_&_Mahindra -0.001506    0.040169
# Axis_Bank            0.001167    0.045828
# SAIL                -0.003463    0.062188
# Shree_Cement         0.003681    0.039917
# Sun_Pharma          -0.001455    0.045033
# Jindal_Steel        -0.004123    0.075108
# Idea_Vodafone       -0.010608    0.104315
# Jet_Airways         -0.009548    0.097972

# %% [markdown]
# # Let us plot & see what they say about stock prices

# %% [raw]
# plot = sns.scatterplot(df_summary['Volatility'], df_summary['Average'])
# plot.axvline(x=0.020257,linestyle='--', color = "red")
# plot.axhline(y=0.000683,linestyle='--', color = "red")
# plt.show()

# %%
plt.scatter(df_std, df_means, edgecolors='r')
plt.axhline(y=0,linestyle='--', color = "red")
plt.xlabel('Volatility')
plt.ylabel('Average')
plt.show()

# %%
df_summary[df_summary['Average'] > 0].sort_values(by = 'Volatility')
# Out:
#                Average  Volatility
# Infosys       0.002794    0.035070
# Shree_Cement  0.003681    0.039917
# Axis_Bank     0.001167    0.045828
# Indian_Hotel  0.000266    0.047131

# %%
df_summary[df_summary['Average'] < 0].sort_values(by = 'Volatility')
# Out:
#                       Average  Volatility
# Mahindra_&_Mahindra -0.001506    0.040169
# Sun_Pharma          -0.001455    0.045033
# SAIL                -0.003463    0.062188
# Jindal_Steel        -0.004123    0.075108
# Jet_Airways         -0.009548    0.097972
# Idea_Vodafone       -0.010608    0.104315
